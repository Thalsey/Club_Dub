# %% [markdown]
# Ok now here is the Jupyter Lab for our thing I guess we need this so here we go

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
pd.set_option('display.max_rows',100)

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %%
pgh_crime_data = pd.read_csv("https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f")
neighborhoods = pd.read_csv("https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/9890875b-c1d1-4e64-8fc9-a4a8dc433745/download/housing.csv")
neighborhood_list = neighborhoods.loc[:, "Neighborhood"]                                             
#pgh_crime_data.head()
#for i in range(pgh_crime_data["INCIDENTNEIGHBORHOOD"].size):
#    if (pgh_crime_data.loc[i, "INCIDENTNEIGHBORHOOD"] not in neighborhood_list):
 #       pgh_crime_data.drop(i)

# %%
count_neighborhood = pgh_crime_data.groupby("INCIDENTNEIGHBORHOOD").count()
count_neighborhood.head()
# Out:
#                        PK  CCR  AGE  GENDER  RACE  ARRESTTIME  ARRESTLOCATION  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center      657  657  653     657   657         657             657
# Allegheny West         75   75   74      75    75          75              75
# Allentown             542  542  537     542   542         542             542
# Arlington             168  168  167     168   168         168             168
# Arlington Heights     101  101  101     101   101         101             101
#
#                       OFFENSES  INCIDENTLOCATION  INCIDENTZONE  INCIDENTTRACT  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center           657               657           657            657
# Allegheny West              75                75            75             75
# Allentown                  542               542           542            542
# Arlington                  168               168           168            168
# Arlington Heights          101               101           101            101
#
#                       COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION    X    Y
# INCIDENTNEIGHBORHOOD
# Allegheny Center                   548                    548  657  657
# Allegheny West                      72                     72   75   75
# Allentown                          512                    512  542  542
# Arlington                          159                    159  168  168
# Arlington Heights                   96                     96  101  101

# %%
count_neighborhood.sort_values("PK")
crime_sorted = count_neighborhood.sort_values("PK")
crime_sorted.rename(columns = {"PK":"COUNT"},inplace = True)
crime_sorted_count = crime_sorted.loc[:,"COUNT"]
crime_sorted_count.head(23)
# Out:
# INCIDENTNEIGHBORHOOD
# Mt. Oliver Neighborhood         2
# Troy Hill-Herrs Island          6
# Mt. Oliver Boro                12
# Ridgemont                      14
# Regent Square                  19
# Swisshelm Park                 20
# New Homestead                  22
# Chartiers City                 23
# Central Northside              23
# East Carnegie                  28
# St. Clair                      31
# Outside County                 36
# Outside State                  39
# Oakwood                        44
# Summer Hill                    45
# Windgap                        60
# Hays                           62
# Fairywood                      62
# Glen Hazel                     69
# Allegheny West                 75
# Golden Triangle/Civic Arena    83
# Mount Oliver                   89
# Polish Hill                    98
# Name: COUNT, dtype: int64

# %%
crime_sorted_count.plot()

# %%
crime_sorted_count.tail()
# Out:
# INCIDENTNEIGHBORHOOD
# Homewood South               1143
# East Allegheny               1242
# Carrick                      1331
# South Side Flats             1956
# Central Business District    2143
# Name: COUNT, dtype: int64

# %%
neighborhoods = pd.read_csv("https://data.wprdc.org/dataset/40188e1c-6d2e-4f20-9391-607bd3054949/resource/9890875b-c1d1-4e64-8fc9-a4a8dc433745/download/housing.csv")
                          
#neighborhoods.head()

# %%
count_neighborhood = pgh_crime_data.groupby("INCIDENTNEIGHBORHOOD").count()

# %%
neighborhood_list = neighborhoods.loc[:, "Neighborhood"]
neighborhood_list
# Out:
# 0              Allegheny Center
# 1                Allegheny West
# 2                     Allentown
# 3                     Arlington
# 4             Arlington Heights
# 5                    Banksville
# 6             Bedford Dwellings
# 7                     Beechview
# 8                   Beltzhoover
# 9                    Bloomfield
# 10                        Bluff
# 11                      Bon Air
# 12             Brighton Heights
# 13                    Brookline
# 14         California-Kirkbride
# 15                      Carrick
# 16    Central Business District
# 17        Central Lawrenceville
# 18            Central Northside
# 19              Central Oakland
# 20               Chartiers City
# 21                      Chateau
# 22              Crafton Heights
# 23             Crawford-Roberts
# 24             Duquesne Heights
# 25               East Allegheny
# 26                East Carnegie
# 27                   East Hills
# 28                 East Liberty
# 29                      Elliott
# 30                       Esplen
# 31                    Fairywood
# 32                     Fineview
# 33                   Friendship
# 34                     Garfield
# 35                   Glen Hazel
# 36                   Greenfield
# 37                         Hays
# 38                    Hazelwood
# 39                Highland Park
# 40               Homewood North
# 41               Homewood South
# 42                Homewood West
# 43                    Knoxville
# 44                      Larimer
# 45                Lincoln Place
# 46     Lincoln-Lemington-Belmar
# 47          Lower Lawrenceville
# 48                   Manchester
# 49           Marshall-Shadeland
# 50                  Middle Hill
# 51                  Morningside
# 52             Mount Washington
# 53                   Mt. Oliver
# 54                New Homestead
# 55                North Oakland
# 56                  North Shore
# 57            Northview Heights
# 58                      Oakwood
# 59                    Overbrook
# 60                  Perry North
# 61                  Perry South
# 62                 Point Breeze
# 63           Point Breeze North
# 64                  Polish Hill
# 65                Regent Square
# 66                    Ridgemont
# 67                    Shadyside
# 68                     Sheraden
# 69                South Oakland
# 70                  South Shore
# 71             South Side Flats
# 72            South Side Slopes
# 73                Spring Garden
# 74        Spring Hill-City View
# 75          Squirrel Hill North
# 76          Squirrel Hill South
# 77                    St. Clair
# 78              Stanton Heights
# 79               Strip District
# 80                  Summer Hill
# 81               Swisshelm Park
# 82              Terrace Village
# 83                    Troy Hill
# 84                   Upper Hill
# 85          Upper Lawrenceville
# 86                     West End
# 87                 West Oakland
# 88                     Westwood
# 89                      Windgap
# Name: Neighborhood, dtype: object

# %%
pgh_schools = pd.read_csv("https://data.wprdc.org/dataset/3cb2b9c2-66e2-4ffa-b0a1-35fb2c6f7230/resource/eb1f8714-e0eb-4614-acfe-dfe0ebab942f/download/school-enrollment-by-detailed-level-of-school-for-the-population-3-years-and-over.csv")
pgh_schools.head()
# Out:
#         Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0   Allegheny Center   1            1389.0               193.000000
# 1     Allegheny West   2             343.0                96.000000
# 2          Allentown   3            2520.0               449.503059
# 3          Arlington   4            1823.0               342.302498
# 4  Arlington Heights   5             213.0               115.000000
#
#    Estimate; Enrolled in school:  Margin of Error; Enrolled in school:  \
# 0                          394.0                            120.000000
# 1                           61.0                             44.000000
# 2                          965.0                            312.800256
# 3                          427.0                            127.722355
# 4                           40.0                             49.000000
#
#    Estimate; Enrolled in school: - Enrolled in nursery school, preschool  \
# 0                                               48.0
# 1                                                0.0
# 2                                               19.0
# 3                                                7.0
# 4                                               28.0
#
#    Margin of Error; Enrolled in school: - Enrolled in nursery school, preschool  \
# 0                                          29.000000
# 1                                          10.000000
# 2                                          22.825424
# 3                                          17.916473
# 4                                          49.000000
#
#    Estimate; Enrolled in school: - Enrolled in kindergarten  \
# 0                                                0.0
# 1                                                0.0
# 2                                               23.0
# 3                                                6.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Enrolled in kindergarten  \
# 0                                          10.000000
# 1                                          10.000000
# 2                                          28.722813
# 3                                          17.916473
# 4                                          10.000000
#
#                     ...                     \
# 0                   ...
# 1                   ...
# 2                   ...
# 3                   ...
# 4                   ...
#
#    Estimate; Enrolled in school: - Enrolled in grade 11  \
# 0                                                0.0
# 1                                                9.0
# 2                                               41.0
# 3                                               37.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Enrolled in grade 11  \
# 0                                          10.000000
# 1                                          12.000000
# 2                                          53.823787
# 3                                          27.000000
# 4                                          10.000000
#
#    Estimate; Enrolled in school: - Enrolled in grade 12  \
# 0                                               21.0
# 1                                                0.0
# 2                                               81.0
# 3                                               17.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Enrolled in grade 12  \
# 0                                          32.000000
# 1                                          10.000000
# 2                                          72.718636
# 3                                          27.856777
# 4                                          10.000000
#
#    Estimate; Enrolled in school: - Enrolled in college, undergraduate years  \
# 0                                              150.0
# 1                                                2.0
# 2                                              125.0
# 3                                              142.0
# 4                                               12.0
#
#    Margin of Error; Enrolled in school: - Enrolled in college, undergraduate years  \
# 0                                          60.000000
# 1                                           4.000000
# 2                                          87.120606
# 3                                          69.231496
# 4                                          14.000000
#
#    Estimate; Enrolled in school: - Graduate or professional school  \
# 0                                               51.0
# 1                                               25.0
# 2                                               74.0
# 3                                               16.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Graduate or professional school  \
# 0                                          35.000000
# 1                                          22.000000
# 2                                         101.469207
# 3                                          18.493242
# 4                                          10.000000
#
#    Estimate; Not enrolled in school  Margin of Error; Not enrolled in school
# 0                             995.0                               135.000000
# 1                             282.0                                74.000000
# 2                            1555.0                               267.807767
# 3                            1396.0                               267.159129
# 4                             173.0                                87.000000
#
# [5 rows x 40 columns]

# %%
# Create a filter function to knock out any district that had less then 300 total eligable students.
schools_new = pgh_schools.loc[pgh_schools['Estimate; Total:'] > 300]

# %%
pd.options.mode.chained_assignment = None
school2 = schools_new
i = 0

while i < school2["Id"].size:
    school2.iloc[i, 1] = school2.iloc[i, 4] / school2.iloc[i, 2]
    i = i + 1

# %%
school2.sort_values(by=['Id'], inplace=True)
i = 0
while i < school2["Id"].size:
    school2.iloc[i, 1] = school2.iloc[i, 1] * 100
    i = i + 1

# %%
school2.iloc[:, 0:2]
# Out:
#                  Neighborhood         Id
# 80             Strip District   7.432432
# 65                Polish Hill   9.714726
# 5                  Banksville  10.615263
# 74              Spring Garden  11.866502
# 17      Central Lawrenceville  12.765957
# 59                    Oakwood  13.235294
# 25             East Allegheny  14.892601
# 37                       Hays  15.425532
# 49         Marshall-Shadeland  15.832206
# 24           Duquesne Heights  16.547968
# 81                Summer Hill  17.213842
# 1              Allegheny West  17.784257
# 45              Lincoln Place  17.785036
# 64         Point Breeze North  18.106996
# 42              Homewood West  18.137255
# 50                Middle Hill  18.456181
# 53           Mount Washington  18.615836
# 89                   Westwood  19.043294
# 18          Central Northside  19.165488
# 30                     Esplen  20.388350
# 14       California-Kirkbride  20.568336
# 84                  Troy Hill  20.584270
# 48                 Manchester  20.748830
# 60                  Overbrook  20.850709
# 36                 Greenfield  20.967306
# 20             Chartiers City  21.071429
# 54                 Mt. Oliver  21.124361
# 31                  Fairywood  21.141838
# 12           Brighton Heights  21.227873
# 8                 Beltzhoover  21.255438
# 82             Swisshelm Park  21.627907
# 51                Morningside  21.906888
# 61                Perry North  22.085048
# 13                  Brookline  22.102215
# 26              East Carnegie  22.466216
# 44                    Larimer  22.732997
# 47        Lower Lawrenceville  22.929688
# 7                   Beechview  22.947233
# 66              Regent Square  22.993062
# 15                    Carrick  23.145038
# 3                   Arlington  23.422929
# 86        Upper Lawrenceville  23.478588
# 63               Point Breeze  23.610579
# 75      Spring Hill-City View  24.836316
# 35                 Glen Hazel  24.962853
# 79            Stanton Heights  24.972594
# 55              New Homestead  25.338895
# 73          South Side Slopes  25.497485
# 9                  Bloomfield  25.711932
# 23           Crawford-Roberts  25.754060
# 62                Perry South  26.139163
# 38                  Hazelwood  26.261383
# 22            Crafton Heights  26.272751
# 27                 East Hills  26.472754
# 41             Homewood South  26.861581
# 90                    Windgap  26.867628
# 28               East Liberty  26.883756
# 11                    Bon Air  26.887872
# 6           Bedford Dwellings  26.938449
# 69                   Sheraden  26.940893
# 32                   Fineview  27.378965
# 34                   Garfield  27.470199
# 39              Highland Park  27.568310
# 52       Mount Oliver Borough  27.767640
# 85                 Upper Hill  28.076718
# 0            Allegheny Center  28.365731
# 46   Lincoln-Lemington-Belmar  29.192419
# 77        Squirrel Hill South  29.277885
# 72           South Side Flats  33.456000
# 33                 Friendship  33.536924
# 43                  Knoxville  34.840020
# 29                    Elliott  34.846029
# 68                  Shadyside  35.319789
# 2                   Allentown  38.293651
# 58          Northview Heights  38.514443
# 16  Central Business District  41.738915
# 40             Homewood North  41.767594
# 88               West Oakland  47.055324
# 76        Squirrel Hill North  53.296604
# 70              South Oakland  54.914089
# 10                      Bluff  57.640324
# 83            Terrace Village  58.322354
# 56              North Oakland  75.190800
# 19            Central Oakland  79.972518
